# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"/Users/ahmedsherif/Downloads/used_cars.csv")
df
# Out:
#          brand                            model  model_year      milage  \
# 0         Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1      Hyundai                     Palisade SEL        2021  34,742 mi.
# 2        Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3     INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4         Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
# ...        ...                              ...         ...         ...
# 4004   Bentley             Continental GT Speed        2023     714 mi.
# 4005      Audi             S4 3.0T Premium Plus        2022  10,900 mi.
# 4006   Porsche                           Taycan        2022   2,116 mi.
# 4007      Ford                     F-150 Raptor        2020  33,000 mi.
# 4008       BMW                     X3 xDrive30i        2020  43,000 mi.
#
#           fuel_type                                             engine  \
# ...

# %%
df.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 376.0+ KB

# %%
df.isnull().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       170
# engine            0
# transmission      0
# ext_col           0
# int_col           0
# accident        113
# clean_title     596
# price             0
# dtype: int64

# %%
df["fuel_type"].value_counts()
# Out:
# fuel_type
# Gasoline          3309
# Hybrid             194
# E85 Flex Fuel      139
# Diesel             116
# –                   45
# Plug-In Hybrid      34
# not supported        2
# Name: count, dtype: int64

# %%
df = df.replace('–',np.nan)

# %%
df["fuel_type"].value_counts()
# Out:
# fuel_type
# Gasoline          3309
# Hybrid             194
# E85 Flex Fuel      139
# Diesel             116
# Plug-In Hybrid      34
# not supported        2
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       215
# engine           45
# transmission      4
# ext_col          15
# int_col         133
# accident        113
# clean_title     596
# price             0
# dtype: int64

# %%
df.dropna(subset = ['fuel_type','engine','transmission','ext_col'],inplace = True)
df
# Out:
#               brand                            model  model_year      milage  \
# 0              Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1           Hyundai                     Palisade SEL        2021  34,742 mi.
# 2             Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3          INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4              Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
# ...             ...                              ...         ...         ...
# 4003  Mercedes-Benz             E-Class E 300 4MATIC        2018  53,705 mi.
# 4004        Bentley             Continental GT Speed        2023     714 mi.
# 4005           Audi             S4 3.0T Premium Plus        2022  10,900 mi.
# 4007           Ford                     F-150 Raptor        2020  33,000 mi.
# 4008            BMW                     X3 xDrive30i        2020  43,000 mi.
#
# ...

# %%
df.isnull().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type         0
# engine            0
# transmission      0
# ext_col           0
# int_col         114
# accident        108
# clean_title     557
# price             0
# dtype: int64

# %%
df.drop(['clean_title'],inplace = True,axis = 1)

# %%
df.isnull().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type         0
# engine            0
# transmission      0
# ext_col           0
# int_col         114
# accident        108
# price             0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# price           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3560 entries, 0 to 4008
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         3560 non-null   object
#  1   model         3560 non-null   object
#  2   model_year    3560 non-null   int64
#  3   milage        3560 non-null   object
#  4   fuel_type     3560 non-null   object
#  5   engine        3560 non-null   object
#  6   transmission  3560 non-null   object
#  7   ext_col       3560 non-null   object
#  8   int_col       3560 non-null   object
#  9   accident      3560 non-null   object
#  10  price         3560 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 333.8+ KB

# %%
milage,price
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 milage,price
#
# NameError: name 'milage' is not defined

# %%
print(f'Number of duplicated rows: {df.duplicated().sum()}')
# Out:
# Number of duplicated rows: 0

# %%
df["price"] = df["price"].replace('[\$,]', '', regex=True).astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/80/hdbs1lwn7tgcy1cvy3nyb3jh0000gn/T/ipykernel_3403/2180386557.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df["price"] = df["price"].replace('[\$,]', '', regex=True).astype(int)

# %%
df['price']
# Out:
# 0        10300
# 1        38005
# 2        54598
# 3        15500
# 4        34999
#          ...
# 4003     25900
# 4004    349950
# 4005     53900
# 4007     62999
# 4008     40000
# Name: price, Length: 3560, dtype: int64

# %%
df['milage'] = df["milage"].replace("[mi.,]",'',regex = True).astype(int)

# %%
df['milage']
# Out:
# 0       51000
# 1       34742
# 2       22372
# 3       88900
# 4        9835
#         ...
# 4003    53705
# 4004      714
# 4005    10900
# 4007    33000
# 4008    43000
# Name: milage, Length: 3560, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3560 entries, 0 to 4008
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         3560 non-null   object
#  1   model         3560 non-null   object
#  2   model_year    3560 non-null   int64
#  3   milage        3560 non-null   int64
#  4   fuel_type     3560 non-null   object
#  5   engine        3560 non-null   object
#  6   transmission  3560 non-null   object
#  7   ext_col       3560 non-null   object
#  8   int_col       3560 non-null   object
#  9   accident      3560 non-null   object
#  10  price         3560 non-null   int64
# dtypes: int64(3), object(8)
# memory usage: 333.8+ KB

# %%
df.to_csv("cleaned_data.csv", index=False)
